# %% [markdown]
# ![logo](Math-Intuition_logo_bold.png)
#
#
# # Lineare Algebra 2 (LA2)
#
#
# **Kapitel I (Eigenwerte und charakteristisches Polynom)**
#
#
# Zugehöriges Math-Intuition Video [Lineare Algebra 2 Intuition](https://www.math-intuition.de/course/la2-intuition-versteher/)

# %% [markdown]
# ## Übungsaufgaben
#
# Stichwort **Diagonalisieren** (Diagonalmatrix $D$ erstellen)
#
# $$ A = \begin{pmatrix}   2 & 1 \\  1 & 2  \end{pmatrix}   ====>   D = \begin{pmatrix}   * & 0 \\  0 & *  \end{pmatrix}$$
#
#
#
# Zugehöriges Math-Intuition Video  [Wofür braucht man das?](https://www.math-intuition.de/lesson/wofuer-braucht-man-das/)

# %% [markdown]
# ### Aufgabe 1.1
#
# Bestimme alle Eigenwerte und die jeweilige algebraische Vielfachheit zu folgender Matrix:
#
# $$ A= \begin{pmatrix}   1 & 1 & 1 \\  0 & 2 & 2 \\  0 & 0 & 3   \end{pmatrix} $$
#
#
# Zugehöriges Math-Intuition Lösungsvideo [Aufgabe 1.1](https://www.math-intuition.de/lesson/la2-aufgabe-1-1/)

# %%
from IPython.display import HTML

HTML(
'''
<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()">
<input type="submit" value="Click here to toggle on/off the raw code.">
</form>
'''
)
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()">
# <input type="submit" value="Click here to toggle on/off the raw code.">
# </form>

# %%
import sympy
print('Imported SymPy version:', sympy.__version__)
sympy_version = sympy.__version__ 
# from sympy import *
from sympy import init_printing, Matrix, symbols
from sympy import *
# from sympy import init_printing, Matrix, symbols, charpoly, eigenvals, diagonalize, det
# Out:
# Imported SymPy version: 1.5.1

# %%
# Enabling LaTex printing
# sym.init_printing(use_latex="mathjax")
init_printing(use_latex="mathjax")
# init_printing

# %%
# creating the python variable A that holds a 3 x 3 matrix
A  = Matrix([[1,1,1],[0,2,2],[0,0,3]])
A
# Out:
# ⎡1  1  1⎤
# ⎢       ⎥
# ⎢0  2  2⎥
# ⎢       ⎥
# ⎣0  0  3⎦

# %%
# https://ipython.readthedocs.io/en/stable/api/generated/IPython.display.html?highlight=.display#classes
from IPython.display import Image 
Image(filename='Math-Intuition_LA2_Kapitel_I_Aufgabe1.1.png')

# %%
x = symbols('x')
p = A.charpoly(x)
char_poly = factor(p)

char_poly
# Out:
# (x - 3)⋅(x - 2)⋅(x - 1)

# %%
A.eigenvals()
# Out:
# {1: 1, 2: 1, 3: 1}

# %%
P, D = A.diagonalize()
D
# Out:
# ⎡1  0  0⎤
# ⎢       ⎥
# ⎢0  2  0⎥
# ⎢       ⎥
# ⎣0  0  3⎦

# %%
D.det()
# Out:
# 6

# %% [markdown]
# ### Lösung
#
# Verwendete Python 3 Bibliothek (Module): SymPy Version {{sympy_version}}
#
# * **Charakteristisches Polynom** {{char_poly}}
#
# ![Ergebnis](Math-Intuition_LA2_Kapitel_I_Aufgabe1.1.png)
#
# * **Eigenwerte**
# * Diagonalisieren
# * **Determinate**

# %% [markdown]
# #### Bezugsdokumente
#
# Source: YouTube video [Matrices in python using sympy](https://www.youtube.com/watch?v=NcIAd0ho43g)

# %%
# https://ipython.readthedocs.io/en/stable/api/generated/IPython.display.html?highlight=.display#classes
from IPython.display import YouTubeVideo
from datetime import timedelta
run_at=int(timedelta(hours=0, minutes=10, seconds=20).total_seconds())
vid = YouTubeVideo("NcIAd0ho43g", start=run_at) # https://www.youtube.com/watch?v=NcIAd0ho43g
display(vid)

# %% [markdown]
# #### Projektablage
#
# https://github.com/griemide/L3/tree/master/Mathe/MAL3-3
